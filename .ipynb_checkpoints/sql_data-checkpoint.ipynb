# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from collections import OrderedDict

# %%
engine=create_engine('postgres://udzvgdqrxtyyth:60a6be53b341bf30f17eab6d20de5236c641ec4bd57c153c957b45218b495f94@ec2-54-164-22-242.compute-1.amazonaws.com:5432/d6dnn6t5pmuopd')

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['clean_arrivals', 'clean_revenues']

# %%
arrivals = Base.classes.clean_arrivals
revenue=Base.classes.clean_revenues

# %%
session = Session(engine)

# %%
session.query(arrivals.longitude).all()[0]
# Out:
# ('19.816667000000002')

# %%
arrivals = Base.classes.clean_arrivals
arrival = session.query(arrivals).all()
features = []
for i in arrival:
    feature_dict = {}
    feature_dict['type'] = 'Feature'
    feature_dict['geometry'] = {
        'type': 'Point',
        'coordinates': [(i.latitude), (i.longitude)]
    }
    feature_dict['properties'] = {
        'country': i.country,
        'country_code': i.country_code,
        "1995": float(i.total_arrivals_1995),
        "1996": float(i.total_arrivals_1996),
        "1997": float(i.total_arrivals_1997),
        "1998": float(i.total_arrivals_1998),
        "1999": float(i.total_arrivals_1999),
        "2000": float(i.total_arrivals_2000),
        "2001": float(i.total_arrivals_2001),
        "2002": float(i.total_arrivals_2002),
        "2003": float(i.total_arrivals_2003),
        "2004": float(i.total_arrivals_2004),
        "2005": float(i.total_arrivals_2005),
        "2006": float(i.total_arrivals_2006),
        "2007": float(i.total_arrivals_2007),
        "2008": float(i.total_arrivals_2008),
        "2009": float(i.total_arrivals_2009),
        "2010": float(i.total_arrivals_2010),
        "2011": float(i.total_arrivals_2011),
        "2012": float(i.total_arrivals_2012),
        "2013": float(i.total_arrivals_2013),
        "2014": float(i.total_arrivals_2014),
        "2015": float(i.total_arrivals_2015),
        "2016": float(i.total_arrivals_2016),
        "2017": float(i.total_arrivals_2017),
        "2018": float(i.total_arrivals_2018),
        "2019": float(i.total_arrivals_2019)

    }
    features.append(feature_dict)
arrivals_dict = {}
arrivals_dict['type'] = 'FeatureCollection'
arrivals_dict['features'] = features
arrivals_dict
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['41.31666667', '19.816667000000002']},
#    'properties': {'country': 'Albania',
#     'country_code': 'ALB',
#     '1995': 304000.0,
#     '1996': 287000.0,
#     '1997': 119000.0,
#     '1998': 184000.0,
#     '1999': 371000.0,
#     '2000': 317000.0,
#     '2001': 354000.0,
#     '2002': 470000.0,
#     '2003': 557000.0,
#     '2004': 645000.0,
#     '2005': 748000.0,
#     '2006': 937000.0,
#     '2007': 1127000.0,
#     '2008': 1420000.0,
#     '2009': 1856000.0,
#     '2010': 2417000.0,
#     '2011': 2932000.0,
#     '2012': 3514000.0,
#     '2013': 3256000.0,
#     '2014': 3673000.0,
#     '2015': 4131000.0,
#     '2016': 4736000.0,
#     '2017': 5118000.0,
#     '2018': 5927000.0,
#     '2019': 6406000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['40.16666667', '44.5']},
#    'properties': {'country': 'Armenia',
#     'country_code': 'ARM',
#     '1995': 12000.0,
#     '1996': 13000.0,
#     '1997': 23000.0,
#     '1998': 32000.0,
#     '1999': 41000.0,
#     '2000': 45000.0,
#     '2001': 123000.0,
#     '2002': 162000.0,
#     '2003': 206000.0,
#     '2004': 263000.0,
#     '2005': 319000.0,
#     '2006': 382000.0,
#     '2007': 511000.0,
#     '2008': 558000.0,
#     '2009': 575000.0,
#     '2010': 684000.0,
#     '2011': 758000.0,
#     '2012': 963000.0,
#     '2013': 1084000.0,
#     '2014': 1204000.0,
#     '2015': 1192000.0,
#     '2016': 1260000.0,
#     '2017': 1495000.0,
#     '2018': 1652000.0,
#     '2019': 1894000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['48.2', '16.366667']},
#    'properties': {'country': 'Austria',
#     'country_code': 'AUT',
#     '1995': 17173000.0,
#     '1996': 17090000.0,
#     '1997': 16647000.0,
#     '1998': 17352000.0,
#     '1999': 17467000.0,
#     '2000': 17982000.0,
#     '2001': 18180000.0,
#     '2002': 18611000.0,
#     '2003': 19078000.0,
#     '2004': 19374000.0,
#     '2005': 19952000.0,
#     '2006': 20269000.0,
#     '2007': 20773000.0,
#     '2008': 21935000.0,
#     '2009': 21355000.0,
#     '2010': 22004000.0,
#     '2011': 23012000.0,
#     '2012': 24151000.0,
#     '2013': 24813000.0,
#     '2014': 25291000.0,
#     '2015': 26728000.0,
#     '2016': 28121000.0,
#     '2017': 29460000.0,
#     '2018': 30816000.0,
#     '2019': 31884000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['40.38333333', '49.866667']},
#    'properties': {'country': 'Azerbaijan',
#     'country_code': 'AZE',
#     '1995': 93000.0,
#     '1996': 210000.0,
#     '1997': 306000.0,
#     '1998': 483000.0,
#     '1999': 602000.0,
#     '2000': 681000.0,
#     '2001': 767000.0,
#     '2002': 834000.0,
#     '2003': 1038000.0,
#     '2004': 1279000.0,
#     '2005': 1177000.0,
#     '2006': 1194000.0,
#     '2007': 1333000.0,
#     '2008': 1899000.0,
#     '2009': 1830000.0,
#     '2010': 1963000.0,
#     '2011': 2239000.0,
#     '2012': 2484000.0,
#     '2013': 2509000.0,
#     '2014': 2298000.0,
#     '2015': 2006000.0,
#     '2016': 2249000.0,
#     '2017': 2697000.0,
#     '2018': 2850000.0,
#     '2019': 3170000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['50.83333333', '4.3333330000000005']},
#    'properties': {'country': 'Belgium',
#     'country_code': 'BEL',
#     '1995': 5560000.0,
#     '1996': 5829000.0,
#     '1997': 6037000.0,
#     '1998': 6179000.0,
#     '1999': 6369000.0,
#     '2000': 6457000.0,
#     '2001': 6452000.0,
#     '2002': 6720000.0,
#     '2003': 6690000.0,
#     '2004': 6710000.0,
#     '2005': 6747000.0,
#     '2006': 6995000.0,
#     '2007': 7045000.0,
#     '2008': 7165000.0,
#     '2009': 6815000.0,
#     '2010': 7186000.0,
#     '2011': 7494000.0,
#     '2012': 7560000.0,
#     '2013': 7684000.0,
#     '2014': 7887000.0,
#     '2015': 8355000.0,
#     '2016': 7481000.0,
#     '2017': 8385000.0,
#     '2018': 9119000.0,
#     '2019': 9343000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['42.68333333', '23.316667000000002']},
#    'properties': {'country': 'Bulgaria',
#     'country_code': 'BGR',
#     '1995': 8005000.0,
#     '1996': 6811000.0,
#     '1997': 7543000.0,
#     '1998': 5240000.0,
#     '1999': 5056000.0,
#     '2000': 4922000.0,
#     '2001': 5104000.0,
#     '2002': 5563000.0,
#     '2003': 6241000.0,
#     '2004': 6982000.0,
#     '2005': 7282000.0,
#     '2006': 7499000.0,
#     '2007': 7726000.0,
#     '2008': 8533000.0,
#     '2009': 7873000.0,
#     '2010': 8374000.0,
#     '2011': 8713000.0,
#     '2012': 8867000.0,
#     '2013': 9192000.0,
#     '2014': 9409000.0,
#     '2015': 9317000.0,
#     '2016': 10604000.0,
#     '2017': 11596000.0,
#     '2018': 12368000.0,
#     '2019': 12552000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['45.8', '16.0']},
#    'properties': {'country': 'Croatia',
#     'country_code': 'HRV',
#     '1995': 16100000.0,
#     '1996': 19085000.0,
#     '1997': 23660000.0,
#     '1998': 25499000.0,
#     '1999': 29215000.0,
#     '2000': 37226000.0,
#     '2001': 40129000.0,
#     '2002': 41737000.0,
#     '2003': 42857000.0,
#     '2004': 44974000.0,
#     '2005': 45762000.0,
#     '2006': 47733000.0,
#     '2007': 52271000.0,
#     '2008': 51336000.0,
#     '2009': 47573000.0,
#     '2010': 49006000.0,
#     '2011': 49969000.0,
#     '2012': 47185000.0,
#     '2013': 48345000.0,
#     '2014': 51168000.0,
#     '2015': 55858000.0,
#     '2016': 57587000.0,
#     '2017': 59238000.0,
#     '2018': 57668000.0,
#     '2019': 60021000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['35.16666667', '33.366667']},
#    'properties': {'country': 'Cyprus',
#     'country_code': 'CYP',
#     '1995': 2253000.0,
#     '1996': 2089000.0,
#     '1997': 2194000.0,
#     '1998': 2357000.0,
#     '1999': 2578000.0,
#     '2000': 2912000.0,
#     '2001': 2841000.0,
#     '2002': 2495000.0,
#     '2003': 2416000.0,
#     '2004': 2478000.0,
#     '2005': 2657000.0,
#     '2006': 2629000.0,
#     '2007': 2671000.0,
#     '2008': 2631000.0,
#     '2009': 2370000.0,
#     '2010': 2450000.0,
#     '2011': 2626000.0,
#     '2012': 2635000.0,
#     '2013': 2626000.0,
#     '2014': 2558000.0,
#     '2015': 2780000.0,
#     '2016': 3286000.0,
#     '2017': 3750000.0,
#     '2018': 4024000.0,
#     '2019': 4117000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['60.16666667', '24.933332999999998']},
#    'properties': {'country': 'Finland',
#     'country_code': 'FIN',
#     '1995': 1779000.0,
#     '1996': 1724000.0,
#     '1997': 1832000.0,
#     '1998': 2644000.0,
#     '1999': 2454000.0,
#     '2000': 2714000.0,
#     '2001': 2826000.0,
#     '2002': 2875000.0,
#     '2003': 2601000.0,
#     '2004': 2840000.0,
#     '2005': 3140000.0,
#     '2006': 3375000.0,
#     '2007': 3519000.0,
#     '2008': 3583000.0,
#     '2009': 3423000.0,
#     '2010': 3670000.0,
#     '2011': 4192000.0,
#     '2012': 4226000.0,
#     '2013': 2797000.0,
#     '2014': 2731000.0,
#     '2015': 2622000.0,
#     '2016': 2789000.0,
#     '2017': 3180000.0,
#     '2018': 3224000.0,
#     '2019': 3290000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['41.68333333', '44.833333']},
#    'properties': {'country': 'Georgia',
#     'country_code': 'GEO',
#     '1995': 85000.0,
#     '1996': 117000.0,
#     '1997': 313000.0,
#     '1998': 317000.0,
#     '1999': 384000.0,
#     '2000': 387000.0,
#     '2001': 302000.0,
#     '2002': 298000.0,
#     '2003': 313000.0,
#     '2004': 368000.0,
#     '2005': 560000.0,
#     '2006': 983000.0,
#     '2007': 1052000.0,
#     '2008': 1290000.0,
#     '2009': 1500000.0,
#     '2010': 2032000.0,
#     '2011': 2712000.0,
#     '2012': 4106000.0,
#     '2013': 4954000.0,
#     '2014': 5004000.0,
#     '2015': 5256000.0,
#     '2016': 5393000.0,
#     '2017': 6483000.0,
#     '2018': 7203000.0,
#     '2019': 7726000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['52.51666667', '13.4']},
#    'properties': {'country': 'Germany',
#     'country_code': 'DEU',
#     '1995': 14847000.0,
#     '1996': 15205000.0,
#     '1997': 15837000.0,
#     '1998': 16511000.0,
#     '1999': 17116000.0,
#     '2000': 18983000.0,
#     '2001': 17861000.0,
#     '2002': 17969000.0,
#     '2003': 18399000.0,
#     '2004': 20137000.0,
#     '2005': 21500000.0,
#     '2006': 23569000.0,
#     '2007': 24421000.0,
#     '2008': 24884000.0,
#     '2009': 24220000.0,
#     '2010': 26875000.0,
#     '2011': 28374000.0,
#     '2012': 30411000.0,
#     '2013': 31545000.0,
#     '2014': 32999000.0,
#     '2015': 34970000.0,
#     '2016': 35555000.0,
#     '2017': 37452000.0,
#     '2018': 38881000.0,
#     '2019': 39563000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['47.5', '19.083333']},
#    'properties': {'country': 'Hungary',
#     'country_code': 'HUN',
#     '1995': 39240000.0,
#     '1996': 39833000.0,
#     '1997': 37315000.0,
#     '1998': 33624000.0,
#     '1999': 28803000.0,
#     '2000': 31141000.0,
#     '2001': 30679000.0,
#     '2002': 31739000.0,
#     '2003': 31412000.0,
#     '2004': 33934000.0,
#     '2005': 36173000.0,
#     '2006': 38318000.0,
#     '2007': 39379000.0,
#     '2008': 39554000.0,
#     '2009': 40624000.0,
#     '2010': 39904000.0,
#     '2011': 41304000.0,
#     '2012': 43565000.0,
#     '2013': 43611000.0,
#     '2014': 45984000.0,
#     '2015': 48345000.0,
#     '2016': 52890000.0,
#     '2017': 54962000.0,
#     '2018': 57667000.0,
#     '2019': 61397000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['64.15', '-21.95']},
#    'properties': {'country': 'Iceland',
#     'country_code': 'ISL',
#     '1995': 211000.0,
#     '1996': 223000.0,
#     '1997': 223000.0,
#     '1998': 255000.0,
#     '1999': 281000.0,
#     '2000': 328000.0,
#     '2001': 329000.0,
#     '2002': 315000.0,
#     '2003': 348000.0,
#     '2004': 405000.0,
#     '2005': 429000.0,
#     '2006': 477000.0,
#     '2007': 539000.0,
#     '2008': 561000.0,
#     '2009': 563000.0,
#     '2010': 559000.0,
#     '2011': 628000.0,
#     '2012': 765000.0,
#     '2013': 900000.0,
#     '2014': 1102000.0,
#     '2015': 1389000.0,
#     '2016': 1891000.0,
#     '2017': 2353000.0,
#     '2018': 2488000.0,
#     '2019': 2202000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['53.31666667', '-6.233333']},
#    'properties': {'country': 'Ireland',
#     'country_code': 'IRL',
#     '1995': 4818000.0,
#     '1996': 5289000.0,
#     '1997': 5587000.0,
#     '1998': 6064000.0,
#     '1999': 6403000.0,
#     '2000': 6646000.0,
#     '2001': 6353000.0,
#     '2002': 6476000.0,
#     '2003': 6764000.0,
#     '2004': 6953000.0,
#     '2005': 7333000.0,
#     '2006': 8001000.0,
#     '2007': 8332000.0,
#     '2008': 8026000.0,
#     '2009': 7189000.0,
#     '2010': 7134000.0,
#     '2011': 7630000.0,
#     '2012': 7550000.0,
#     '2013': 8260000.0,
#     '2014': 8813000.0,
#     '2015': 9528000.0,
#     '2016': 10100000.0,
#     '2017': 10338000.0,
#     '2018': 10926000.0,
#     '2019': 10951000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['41.9', '12.483333']},
#    'properties': {'country': 'Italy',
#     'country_code': 'ITA',
#     '1995': 55706000.0,
#     '1996': 59805000.0,
#     '1997': 57998000.0,
#     '1998': 58499000.0,
#     '1999': 59521000.0,
#     '2000': 62702000.0,
#     '2001': 60960000.0,
#     '2002': 63561000.0,
#     '2003': 63026000.0,
#     '2004': 58480000.0,
#     '2005': 59230000.0,
#     '2006': 66353000.0,
#     '2007': 70271000.0,
#     '2008': 70719000.0,
#     '2009': 71692000.0,
#     '2010': 73225000.0,
#     '2011': 75866000.0,
#     '2012': 76293000.0,
#     '2013': 76762000.0,
#     '2014': 77694000.0,
#     '2015': 81068000.0,
#     '2016': 84925000.0,
#     '2017': 89931000.0,
#     '2018': 93228601.56,
#     '2019': 95399000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['56.95', '24.1']},
#    'properties': {'country': 'Latvia',
#     'country_code': 'LVA',
#     '1995': 1633000.0,
#     '1996': 1750000.0,
#     '1997': 1842000.0,
#     '1998': 1788000.0,
#     '1999': 1738000.0,
#     '2000': 1882000.0,
#     '2001': 2061000.0,
#     '2002': 2297000.0,
#     '2003': 2524000.0,
#     '2004': 3127000.0,
#     '2005': 3791000.0,
#     '2006': 4649000.0,
#     '2007': 5209000.0,
#     '2008': 5496000.0,
#     '2009': 4727000.0,
#     '2010': 5042000.0,
#     '2011': 5538000.0,
#     '2012': 5569000.0,
#     '2013': 5822000.0,
#     '2014': 6246000.0,
#     '2015': 6842000.0,
#     '2016': 6797000.0,
#     '2017': 7726000.0,
#     '2018': 7775000.0,
#     '2019': 8342000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['47.13333333', '9.516667']},
#    'properties': {'country': 'Liechtenstein',
#     'country_code': 'LIE',
#     '1995': 59000.0,
#     '1996': 56000.0,
#     '1997': 57000.0,
#     '1998': 59000.0,
#     '1999': 60000.0,
#     '2000': 61599.998470000006,
#     '2001': 56500.0,
#     '2002': 48700.00076,
#     '2003': 49000.0,
#     '2004': 48500.0,
#     '2005': 49799.99924,
#     '2006': 54900.001529999994,
#     '2007': 72800.00305,
#     '2008': 72900.00153,
#     '2009': 66500.0,
#     '2010': 64300.00305,
#     '2011': 67000.0,
#     '2012': 62400.001529999994,
#     '2013': 59599.998470000006,
#     '2014': 61299.99924,
#     '2015': 56700.00076,
#     '2016': 69099.99847,
#     '2017': 79300.00305,
#     '2018': 85300.00305,
#     '2019': 98099.99847}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['49.6', '6.116667']},
#    'properties': {'country': 'Luxembourg',
#     'country_code': 'LUX',
#     '1995': 768000.0,
#     '1996': 724000.0,
#     '1997': 778000.0,
#     '1998': 789000.0,
#     '1999': 863000.0,
#     '2000': 852000.0,
#     '2001': 836000.0,
#     '2002': 885000.0,
#     '2003': 867000.0,
#     '2004': 878000.0,
#     '2005': 913000.0,
#     '2006': 908000.0,
#     '2007': 914000.0,
#     '2008': 877000.0,
#     '2009': 847000.0,
#     '2010': 805000.0,
#     '2011': 874000.0,
#     '2012': 950000.0,
#     '2013': 945000.0,
#     '2014': 1038000.0,
#     '2015': 1090000.0,
#     '2016': 1054000.0,
#     '2017': 1046000.0,
#     '2018': 1018000.0,
#     '2019': 1041000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['42.0', '21.433332999999998']},
#    'properties': {'country': 'Macedonia',
#     'country_code': 'MKD',
#     '1995': 147000.0,
#     '1996': 136000.0,
#     '1997': 121000.0,
#     '1998': 157000.0,
#     '1999': 181000.0,
#     '2000': 224000.0,
#     '2001': 99000.0,
#     '2002': 123000.0,
#     '2003': 158000.0,
#     '2004': 165000.0,
#     '2005': 197000.0,
#     '2006': 202000.0,
#     '2007': 230000.0,
#     '2008': 255000.0,
#     '2009': 259000.0,
#     '2010': 262000.0,
#     '2011': 327000.0,
#     '2012': 351000.0,
#     '2013': 400000.0,
#     '2014': 425000.0,
#     '2015': 486000.0,
#     '2016': 510000.0,
#     '2017': 631000.0,
#     '2018': 707000.0,
#     '2019': 758000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['35.88333333', '14.5']},
#    'properties': {'country': 'Malta',
#     'country_code': 'MLT',
#     '1995': 1193000.0,
#     '1996': 1123000.0,
#     '1997': 1238000.0,
#     '1998': 1326000.0,
#     '1999': 1402000.0,
#     '2000': 1387000.0,
#     '2001': 1439000.0,
#     '2002': 1483000.0,
#     '2003': 1512000.0,
#     '2004': 1428000.0,
#     '2005': 1484000.0,
#     '2006': 1521000.0,
#     '2007': 1723000.0,
#     '2008': 1832000.0,
#     '2009': 1608000.0,
#     '2010': 1815000.0,
#     '2011': 1916000.0,
#     '2012': 2007000.0,
#     '2013': 2013000.0,
#     '2014': 2162000.0,
#     '2015': 2383000.0,
#     '2016': 2592000.0,
#     '2017': 2944000.0,
#     '2018': 3232000.0,
#     '2019': 3519000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['47.0', '28.85']},
#    'properties': {'country': 'Moldova',
#     'country_code': 'MDA',
#     '1995': 32000.0,
#     '1996': 29000.0,
#     '1997': 21000.0,
#     '1998': 19000.0,
#     '1999': 14000.0,
#     '2000': 18000.0,
#     '2001': 16000.0,
#     '2002': 18000.0,
#     '2003': 21000.0,
#     '2004': 69000.0,
#     '2005': 67000.0,
#     '2006': 63000.0,
#     '2007': 70000.0,
#     '2008': 73000.0,
#     '2009': 60000.0,
#     '2010': 64000.0,
#     '2011': 75000.0,
#     '2012': 89000.0,
#     '2013': 95599.99847,
#     '2014': 93900.00153,
#     '2015': 94400.00153,
#     '2016': 121000.0,
#     '2017': 145000.0,
#     '2018': 160000.0,
#     '2019': 174000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['43.73333333', '7.4166669999999995']},
#    'properties': {'country': 'Monaco',
#     'country_code': 'MCO',
#     '1995': 233000.0,
#     '1996': 226000.0,
#     '1997': 259000.0,
#     '1998': 278000.0,
#     '1999': 278000.0,
#     '2000': 300000.0,
#     '2001': 270000.0,
#     '2002': 263000.0,
#     '2003': 235000.0,
#     '2004': 250000.0,
#     '2005': 286000.0,
#     '2006': 313000.0,
#     '2007': 328000.0,
#     '2008': 324000.0,
#     '2009': 265000.0,
#     '2010': 279000.0,
#     '2011': 295000.0,
#     '2012': 292000.0,
#     '2013': 328000.0,
#     '2014': 329000.0,
#     '2015': 331000.0,
#     '2016': 336000.0,
#     '2017': 355000.0,
#     '2018': 347000.0,
#     '2019': 363000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['52.35', '4.9166669999999995']},
#    'properties': {'country': 'Netherlands',
#     'country_code': 'NLD',
#     '1995': 6574000.0,
#     '1996': 6580000.0,
#     '1997': 7841000.0,
#     '1998': 9312000.0,
#     '1999': 9874000.0,
#     '2000': 10003000.0,
#     '2001': 9500000.0,
#     '2002': 9595000.0,
#     '2003': 9181000.0,
#     '2004': 9646000.0,
#     '2005': 10012000.0,
#     '2006': 10739000.0,
#     '2007': 11008000.0,
#     '2008': 10104000.0,
#     '2009': 9921000.0,
#     '2010': 10883000.0,
#     '2011': 11300000.0,
#     '2012': 11680000.0,
#     '2013': 12783000.0,
#     '2014': 13925000.0,
#     '2015': 15007000.0,
#     '2016': 15828000.0,
#     '2017': 17924000.0,
#     '2018': 18780000.0,
#     '2019': 20129000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['59.91666667', '10.75']},
#    'properties': {'country': 'Norway',
#     'country_code': 'NOR',
#     '1995': 2880000.0,
#     '1996': 2746000.0,
#     '1997': 2702000.0,
#     '1998': 3256000.0,
#     '1999': 3223000.0,
#     '2000': 3104000.0,
#     '2001': 3073000.0,
#     '2002': 3111000.0,
#     '2003': 3269000.0,
#     '2004': 3628000.0,
#     '2005': 3824000.0,
#     '2006': 4070000.0,
#     '2007': 4377000.0,
#     '2008': 4347000.0,
#     '2009': 4346000.0,
#     '2010': 4767000.0,
#     '2011': 4963000.0,
#     '2012': 4538000.0,
#     '2013': 4778000.0,
#     '2014': 4855000.0,
#     '2015': 5361000.0,
#     '2016': 5960000.0,
#     '2017': 6252000.0,
#     '2018': 5688000.0,
#     '2019': 5879000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['52.25', '21.0']},
#    'properties': {'country': 'Poland',
#     'country_code': 'POL',
#     '1995': 82244000.0,
#     '1996': 87439000.0,
#     '1997': 87817000.0,
#     '1998': 88592000.0,
#     '1999': 89118000.0,
#     '2000': 84515000.0,
#     '2001': 61431000.0,
#     '2002': 50735000.0,
#     '2003': 52130000.0,
#     '2004': 61918000.0,
#     '2005': 64606000.0,
#     '2006': 65115000.0,
#     '2007': 66208000.0,
#     '2008': 59935000.0,
#     '2009': 53840000.0,
#     '2010': 58340000.0,
#     '2011': 60745000.0,
#     '2012': 67390000.0,
#     '2013': 72310000.0,
#     '2014': 73750000.0,
#     '2015': 77743000.0,
#     '2016': 80476000.0,
#     '2017': 83804000.0,
#     '2018': 85946000.0,
#     '2019': 88515000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['38.71666667', '-9.133333']},
#    'properties': {'country': 'Portugal',
#     'country_code': 'PRT',
#     '1995': 9511000.0,
#     '1996': 9730000.0,
#     '1997': 10172000.0,
#     '1998': 11295000.0,
#     '1999': 11632000.0,
#     '2000': 12097000.0,
#     '2001': 12167000.0,
#     '2002': 11644000.0,
#     '2003': 11707000.0,
#     '2004': 10639000.0,
#     '2005': 10612000.0,
#     '2006': 11282000.0,
#     '2007': 6788000.0,
#     '2008': 6962000.0,
#     '2009': 6439000.0,
#     '2010': 6756000.0,
#     '2011': 7264000.0,
#     '2012': 7503000.0,
#     '2013': 9177000.0,
#     '2014': 10497000.0,
#     '2015': 11723000.0,
#     '2016': 13359000.0,
#     '2017': 15432000.0,
#     '2018': 16186000.0,
#     '2019': 17174000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['44.43333333', '26.1']},
#    'properties': {'country': 'Romania',
#     'country_code': 'ROU',
#     '1995': 5445000.0,
#     '1996': 5205000.0,
#     '1997': 5149000.0,
#     '1998': 4831000.0,
#     '1999': 5224000.0,
#     '2000': 5264000.0,
#     '2001': 4938000.0,
#     '2002': 4794000.0,
#     '2003': 5595000.0,
#     '2004': 6600000.0,
#     '2005': 5839000.0,
#     '2006': 6037000.0,
#     '2007': 7722000.0,
#     '2008': 8862000.0,
#     '2009': 7575000.0,
#     '2010': 7498000.0,
#     '2011': 7611000.0,
#     '2012': 7937000.0,
#     '2013': 8019000.0,
#     '2014': 8442000.0,
#     '2015': 9331000.0,
#     '2016': 10223000.0,
#     '2017': 10926000.0,
#     '2018': 11720000.0,
#     '2019': 12815000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['55.75', '37.6']},
#    'properties': {'country': 'Russia',
#     'country_code': 'RUS',
#     '1995': 10290000.0,
#     '1996': 16208000.0,
#     '1997': 17463000.0,
#     '1998': 16188000.0,
#     '1999': 18820000.0,
#     '2000': 21169000.0,
#     '2001': 21595000.0,
#     '2002': 23309000.0,
#     '2003': 22521000.0,
#     '2004': 22064000.0,
#     '2005': 22201000.0,
#     '2006': 22486000.0,
#     '2007': 22909000.0,
#     '2008': 23676000.0,
#     '2009': 21339000.0,
#     '2010': 22281000.0,
#     '2011': 24932000.0,
#     '2012': 28177000.0,
#     '2013': 30792000.0,
#     '2014': 32421000.0,
#     '2015': 33729000.0,
#     '2016': 24571000.0,
#     '2017': 24390000.0,
#     '2018': 24551000.0,
#     '2019': 24419000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['43.93333333', '12.416667']},
#    'properties': {'country': 'San Marino',
#     'country_code': 'SMR',
#     '1995': 3368000.0,
#     '1996': 3345000.0,
#     '1997': 3308000.0,
#     '1998': 3264000.0,
#     '1999': 3148000.0,
#     '2000': 3071000.0,
#     '2001': 3036000.0,
#     '2002': 3102000.0,
#     '2003': 2882000.0,
#     '2004': 2812000.0,
#     '2005': 2107000.0,
#     '2006': 2136000.0,
#     '2007': 2164000.0,
#     '2008': 2112000.0,
#     '2009': 2056000.0,
#     '2010': 1976000.0,
#     '2011': 2038000.0,
#     '2012': 1869000.0,
#     '2013': 1905000.0,
#     '2014': 2004000.0,
#     '2015': 1888000.0,
#     '2016': 2000000.0,
#     '2017': 1937000.0,
#     '2018': 1874000.0,
#     '2019': 1904000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['46.05', '14.516667000000002']},
#    'properties': {'country': 'Slovenia',
#     'country_code': 'SVN',
#     '1995': 732000.0,
#     '1996': 832000.0,
#     '1997': 974000.0,
#     '1998': 977000.0,
#     '1999': 884000.0,
#     '2000': 1090000.0,
#     '2001': 1219000.0,
#     '2002': 1302000.0,
#     '2003': 1373000.0,
#     '2004': 1499000.0,
#     '2005': 1555000.0,
#     '2006': 1617000.0,
#     '2007': 1751000.0,
#     '2008': 1958000.0,
#     '2009': 1824000.0,
#     '2010': 2049000.0,
#     '2011': 2236000.0,
#     '2012': 2377000.0,
#     '2013': 2502000.0,
#     '2014': 2675000.0,
#     '2015': 3022000.0,
#     '2016': 3397000.0,
#     '2017': 3991000.0,
#     '2018': 4425000.0,
#     '2019': 4702000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['40.4', '-3.683333']},
#    'properties': {'country': 'Spain',
#     'country_code': 'ESP',
#     '1995': 52460000.0,
#     '1996': 55077000.0,
#     '1997': 62415000.0,
#     '1998': 68068000.0,
#     '1999': 72040000.0,
#     '2000': 74580000.0,
#     '2001': 75564000.0,
#     '2002': 79313000.0,
#     '2003': 82326000.0,
#     '2004': 85981000.0,
#     '2005': 92563000.0,
#     '2006': 96152000.0,
#     '2007': 98907000.0,
#     '2008': 97670000.0,
#     '2009': 91899000.0,
#     '2010': 93744000.0,
#     '2011': 99187000.0,
#     '2012': 98128000.0,
#     '2013': 103231000.0,
#     '2014': 107144000.0,
#     '2015': 109834000.0,
#     '2016': 115561000.0,
#     '2017': 121717000.0,
#     '2018': 124456000.0,
#     '2019': 126170000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['59.33333333', '18.05']},
#    'properties': {'country': 'Sweden',
#     'country_code': 'SWE',
#     '1995': 2310000.0,
#     '1996': 2376000.0,
#     '1997': 2388000.0,
#     '1998': 2573000.0,
#     '1999': 2595000.0,
#     '2000': 3828000.0,
#     '2001': 4108000.0,
#     '2002': 4276000.0,
#     '2003': 4268000.0,
#     '2004': 4676000.0,
#     '2005': 4883000.0,
#     '2006': 4729000.0,
#     '2007': 5224000.0,
#     '2008': 4555000.0,
#     '2009': 4899000.0,
#     '2010': 5183000.0,
#     '2011': 11567000.0,
#     '2012': 12372000.0,
#     '2013': 10980000.0,
#     '2014': 10522000.0,
#     '2015': 6482000.0,
#     '2016': 6782000.0,
#     '2017': 7054000.0,
#     '2018': 7440000.0,
#     '2019': 7616000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['39.93333333', '32.866667']},
#    'properties': {'country': 'Turkey',
#     'country_code': 'TUR',
#     '1995': 7727000.0,
#     '1996': 8614000.0,
#     '1997': 9689000.0,
#     '1998': 9753000.0,
#     '1999': 7487000.0,
#     '2000': 10428000.0,
#     '2001': 11619000.0,
#     '2002': 13256000.0,
#     '2003': 14030000.0,
#     '2004': 17517000.0,
#     '2005': 21125000.0,
#     '2006': 19820000.0,
#     '2007': 27215000.0,
#     '2008': 31138000.0,
#     '2009': 31760000.0,
#     '2010': 32997000.0,
#     '2011': 36769000.0,
#     '2012': 37715000.0,
#     '2013': 39861000.0,
#     '2014': 41627000.0,
#     '2015': 41114000.0,
#     '2016': 30907000.0,
#     '2017': 37970000.0,
#     '2018': 46113000.0,
#     '2019': 51747000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['50.43333333', '30.516666999999998']},
#    'properties': {'country': 'Ukraine',
#     'country_code': 'UKR',
#     '1995': 6127000.0,
#     '1996': 6750000.0,
#     '1997': 14743000.0,
#     '1998': 12003000.0,
#     '1999': 10990000.0,
#     '2000': 11691000.0,
#     '2001': 11877000.0,
#     '2002': 12793000.0,
#     '2003': 15161000.0,
#     '2004': 18583000.0,
#     '2005': 20489000.0,
#     '2006': 21714000.0,
#     '2007': 26162000.0,
#     '2008': 28827000.0,
#     '2009': 24033000.0,
#     '2010': 24114000.0,
#     '2011': 24535000.0,
#     '2012': 25061000.0,
#     '2013': 26025000.0,
#     '2014': 13227000.0,
#     '2015': 13025000.0,
#     '2016': 13734000.0,
#     '2017': 14579000.0,
#     '2018': 14342000.0,
#     '2019': 13710000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['51.5', '-0.083333']},
#    'properties': {'country': 'United Kingdom',
#     'country_code': 'GBR',
#     '1995': 23537000.0,
#     '1996': 25163000.0,
#     '1997': 25515000.0,
#     '1998': 25745000.0,
#     '1999': 25394000.0,
#     '2000': 25209000.0,
#     '2001': 22835000.0,
#     '2002': 24180000.0,
#     '2003': 24715000.0,
#     '2004': 27755000.0,
#     '2005': 29970000.0,
#     '2006': 32713000.0,
#     '2007': 32778000.0,
#     '2008': 31888000.0,
#     '2009': 31072000.0,
#     '2010': 30398000.0,
#     '2011': 31886000.0,
#     '2012': 32221000.0,
#     '2013': 33567000.0,
#     '2014': 35337000.0,
#     '2015': 36792000.0,
#     '2016': 39129000.0,
#     '2017': 41080000.0,
#     '2018': 40283000.0,
#     '2019': 40857000.0}}]}

# %%
revenues = Base.classes.clean_revenues
revenue = session.query(revenues).all()
features = []
for i in revenue:
    feature_dict = {}
    feature_dict['type'] = 'Feature'
    feature_dict['geometry'] = {
        'type': 'Point',
        'coordinates': [(i.latitude), (i.longitude)]
    }
    feature_dict['properties'] = {
        'country': i.country,
        'country_code': i.country_code,
        "1995": float(i.total_revenues_1995),
        "1996": float(i.total_revenues_1996),
        "1997": float(i.total_revenues_1997),
        "1998": float(i.total_revenues_1998),
        "1999": float(i.total_revenues_1999),
        "2000": float(i.total_revenues_2000),
        "2001": float(i.total_revenues_2001),
        "2002": float(i.total_revenues_2002),
        "2003": float(i.total_revenues_2003),
        "2004": float(i.total_revenues_2004),
        "2005": float(i.total_revenues_2005),
        "2006": float(i.total_revenues_2006),
        "2007": float(i.total_revenues_2007),
        "2008": float(i.total_revenues_2008),
        "2009": float(i.total_revenues_2009),
        "2010": float(i.total_revenues_2010),
        "2011": float(i.total_revenues_2011),
        "2012": float(i.total_revenues_2012),
        "2013": float(i.total_revenues_2013),
        "2014": float(i.total_revenues_2014),
        "2015": float(i.total_revenues_2015),
        "2016": float(i.total_revenues_2016),
        "2017": float(i.total_revenues_2017),
        "2018": float(i.total_revenues_2018),
        "2019": float(i.total_revenues_2019)

    }
    features.append(feature_dict)
revenues_dict = {}
revenues_dict['type'] = 'FeatureCollection'
revenues_dict['features'] = features
revenues_dict
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['41.31666667', '19.816667000000002']},
#    'properties': {'country': 'Albania',
#     'country_code': 'ALB',
#     '1995': 70000000.0,
#     '1996': 94000000.0,
#     '1997': 34000000.0,
#     '1998': 60000000.0,
#     '1999': 218000000.0,
#     '2000': 398000000.0,
#     '2001': 451000000.0,
#     '2002': 492000000.0,
#     '2003': 537000000.0,
#     '2004': 756000000.0,
#     '2005': 880000000.0,
#     '2006': 1057000000.0,
#     '2007': 1479000000.0,
#     '2008': 1850000000.0,
#     '2009': 2013000000.0,
#     '2010': 1778000000.0,
#     '2011': 1833000000.0,
#     '2012': 1623000000.0,
#     '2013': 1670000000.0,
#     '2014': 1849000000.0,
#     '2015': 1613000000.0,
#     '2016': 1821000000.0,
#     '2017': 2050000000.0,
#     '2018': 2306000000.0,
#     '2019': 2458000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['40.16666667', '44.5']},
#    'properties': {'country': 'Armenia',
#     'country_code': 'ARM',
#     '1995': 14000000.0,
#     '1996': 18000000.0,
#     '1997': 33000000.0,
#     '1998': 41000000.0,
#     '1999': 47000000.0,
#     '2000': 52000000.0,
#     '2001': 81000000.0,
#     '2002': 81000000.0,
#     '2003': 90000000.0,
#     '2004': 189000000.0,
#     '2005': 243000000.0,
#     '2006': 406000000.0,
#     '2007': 522000000.0,
#     '2008': 564000000.0,
#     '2009': 570000000.0,
#     '2010': 694000000.0,
#     '2011': 762000000.0,
#     '2012': 853000000.0,
#     '2013': 905000000.0,
#     '2014': 994000000.0,
#     '2015': 956000000.0,
#     '2016': 1037000000.0,
#     '2017': 1224000000.0,
#     '2018': 1358000000.0,
#     '2019': 1553000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['40.38333333', '49.866667']},
#    'properties': {'country': 'Azerbaijan',
#     'country_code': 'AZE',
#     '1995': 87000000.0,
#     '1996': 57000000.0,
#     '1997': 176000000.0,
#     '1998': 143000000.0,
#     '1999': 93000000.0,
#     '2000': 68000000.0,
#     '2001': 57000000.0,
#     '2002': 63000000.0,
#     '2003': 70000000.0,
#     '2004': 79000000.0,
#     '2005': 100000000.0,
#     '2006': 201000000.0,
#     '2007': 317000000.0,
#     '2008': 382000000.0,
#     '2009': 545000000.0,
#     '2010': 792000000.0,
#     '2011': 1500000000.0,
#     '2012': 2634000000.0,
#     '2013': 2618000000.0,
#     '2014': 2713000000.0,
#     '2015': 2535000000.0,
#     '2016': 2855000000.0,
#     '2017': 3214000000.0,
#     '2018': 2830000000.0,
#     '2019': 2004099976.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['53.9', '27.566667']},
#    'properties': {'country': 'Belarus',
#     'country_code': 'BLR',
#     '1995': 28000000.0,
#     '1996': 61000000.0,
#     '1997': 40000000.0,
#     '1998': 54000000.0,
#     '1999': 92000000.0,
#     '2000': 188000000.0,
#     '2001': 272000000.0,
#     '2002': 295000000.0,
#     '2003': 339000000.0,
#     '2004': 362000000.0,
#     '2005': 346000000.0,
#     '2006': 401000000.0,
#     '2007': 479000000.0,
#     '2008': 585000000.0,
#     '2009': 563000000.0,
#     '2010': 665000000.0,
#     '2011': 747000000.0,
#     '2012': 986000000.0,
#     '2013': 1156000000.0,
#     '2014': 1230000000.0,
#     '2015': 1013000000.0,
#     '2016': 1019000000.0,
#     '2017': 1124500000.0,
#     '2018': 1221000000.0,
#     '2019': 1290000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['42.68333333', '23.316667000000002']},
#    'properties': {'country': 'Bulgaria',
#     'country_code': 'BGR',
#     '1995': 662000000.0,
#     '1996': 541000000.0,
#     '1997': 517000000.0,
#     '1998': 1150000000.0,
#     '1999': 1184000000.0,
#     '2000': 1364000000.0,
#     '2001': 1262000000.0,
#     '2002': 1392000000.0,
#     '2003': 2051000000.0,
#     '2004': 2796000000.0,
#     '2005': 3063000000.0,
#     '2006': 3317000000.0,
#     '2007': 4181000000.0,
#     '2008': 4852000000.0,
#     '2009': 4273000000.0,
#     '2010': 3807000000.0,
#     '2011': 4297000000.0,
#     '2012': 3975000000.0,
#     '2013': 4410000000.0,
#     '2014': 4518000000.0,
#     '2015': 3583000000.0,
#     '2016': 4164000000.0,
#     '2017': 4678000000.0,
#     '2018': 5055000000.0,
#     '2019': 4825000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['35.16666667', '33.366667']},
#    'properties': {'country': 'Cyprus',
#     'country_code': 'CYP',
#     '1995': 2018044189.0,
#     '1996': 1904723511.0,
#     '1997': 1850360596.0,
#     '1998': 1918303589.0,
#     '1999': 2115000000.0,
#     '2000': 2137000000.0,
#     '2001': 2203000000.0,
#     '2002': 2178000000.0,
#     '2003': 2325000000.0,
#     '2004': 2552000000.0,
#     '2005': 2644000000.0,
#     '2006': 2692007568.0,
#     '2007': 3107000000.0,
#     '2008': 3232000000.0,
#     '2009': 2476000000.0,
#     '2010': 2137000000.0,
#     '2011': 2603000000.0,
#     '2012': 2603000000.0,
#     '2013': 2930000000.0,
#     '2014': 2924000000.0,
#     '2015': 2525664307.0,
#     '2016': 2870000000.0,
#     '2017': 3274000000.0,
#     '2018': 3449000000.0,
#     '2019': 3245000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['60.16666667', '24.933332999999998']},
#    'properties': {'country': 'Finland',
#     'country_code': 'FIN',
#     '1995': 2383000000.0,
#     '1996': 2408000000.0,
#     '1997': 2358000000.0,
#     '1998': 2371000000.0,
#     '1999': 2236000000.0,
#     '2000': 2035000000.0,
#     '2001': 2066000000.0,
#     '2002': 2238000000.0,
#     '2003': 2679000000.0,
#     '2004': 2977000000.0,
#     '2005': 3069000000.0,
#     '2006': 3515000000.0,
#     '2007': 4287000000.0,
#     '2008': 4875000000.0,
#     '2009': 4072000000.0,
#     '2010': 4496000000.0,
#     '2011': 5615000000.0,
#     '2012': 5418000000.0,
#     '2013': 5774000000.0,
#     '2014': 5409000000.0,
#     '2015': 4011000000.0,
#     '2016': 4017000000.0,
#     '2017': 5210000000.0,
#     '2018': 5763000000.0,
#     '2019': 5944000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['52.51666667', '13.4']},
#    'properties': {'country': 'Germany',
#     'country_code': 'DEU',
#     '1995': 24053000000.0,
#     '1996': 23982000000.0,
#     '1997': 24500000000.0,
#     '1998': 25806000000.0,
#     '1999': 25327000000.0,
#     '2000': 24943000000.0,
#     '2001': 24182000000.0,
#     '2002': 26717000000.0,
#     '2003': 30129000000.0,
#     '2004': 36417000000.0,
#     '2005': 40518000000.0,
#     '2006': 45560000000.0,
#     '2007': 49320000000.0,
#     '2008': 53402000000.0,
#     '2009': 47499000000.0,
#     '2010': 49116000000.0,
#     '2011': 53465000000.0,
#     '2012': 51626000000.0,
#     '2013': 55486000000.0,
#     '2014': 58721000000.0,
#     '2015': 50669000000.0,
#     '2016': 52234000000.0,
#     '2017': 55750000000.0,
#     '2018': 59446000000.0,
#     '2019': 58201000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['47.5', '19.083333']},
#    'properties': {'country': 'Hungary',
#     'country_code': 'HUN',
#     '1995': 2938000000.0,
#     '1996': 3589000000.0,
#     '1997': 3824000000.0,
#     '1998': 3688000000.0,
#     '1999': 3622000000.0,
#     '2000': 3809000000.0,
#     '2001': 4191000000.0,
#     '2002': 3774000000.0,
#     '2003': 4119000000.0,
#     '2004': 4009000000.0,
#     '2005': 4761000000.0,
#     '2006': 4998000000.0,
#     '2007': 5628000000.0,
#     '2008': 7533000000.0,
#     '2009': 7013000000.0,
#     '2010': 6595000000.0,
#     '2011': 7239000000.0,
#     '2012': 6149000000.0,
#     '2013': 6671000000.0,
#     '2014': 7483000000.0,
#     '2015': 6929000000.0,
#     '2016': 7481000000.0,
#     '2017': 8448000000.0,
#     '2018': 9618000000.0,
#     '2019': 10196000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['47.0', '28.85']},
#    'properties': {'country': 'Moldova',
#     'country_code': 'MDA',
#     '1995': 71000000.0,
#     '1996': 50000000.0,
#     '1997': 74000000.0,
#     '1998': 64000000.0,
#     '1999': 49000000.0,
#     '2000': 57000000.0,
#     '2001': 58000000.0,
#     '2002': 72000000.0,
#     '2003': 79000000.0,
#     '2004': 112000000.0,
#     '2005': 138000000.0,
#     '2006': 150000000.0,
#     '2007': 229000000.0,
#     '2008': 293000000.0,
#     '2009': 240000000.0,
#     '2010': 222000000.0,
#     '2011': 253000000.0,
#     '2012': 279000000.0,
#     '2013': 324000000.0,
#     '2014': 328000000.0,
#     '2015': 300000000.0,
#     '2016': 344000000.0,
#     '2017': 443000000.0,
#     '2018': 500000000.0,
#     '2019': 532000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['59.91666667', '10.75']},
#    'properties': {'country': 'Norway',
#     'country_code': 'NOR',
#     '1995': 2730000000.0,
#     '1996': 2770000000.0,
#     '1997': 2570000000.0,
#     '1998': 2545000000.0,
#     '1999': 2750000000.0,
#     '2000': 2521000000.0,
#     '2001': 2380000000.0,
#     '2002': 2581000000.0,
#     '2003': 2989000000.0,
#     '2004': 3531000000.0,
#     '2005': 4243000000.0,
#     '2006': 4289000000.0,
#     '2007': 5322000000.0,
#     '2008': 5702000000.0,
#     '2009': 4949000000.0,
#     '2010': 5299000000.0,
#     '2011': 6565000000.0,
#     '2012': 6784000000.0,
#     '2013': 7175000000.0,
#     '2014': 7503000000.0,
#     '2015': 6370000000.0,
#     '2016': 6285000000.0,
#     '2017': 6840000000.0,
#     '2018': 7096000000.0,
#     '2019': 6929000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['52.25', '21.0']},
#    'properties': {'country': 'Poland',
#     'country_code': 'POL',
#     '1995': 6927000000.0,
#     '1996': 8764000000.0,
#     '1997': 9053000000.0,
#     '1998': 8321000000.0,
#     '1999': 6498000000.0,
#     '2000': 6128000000.0,
#     '2001': 5121000000.0,
#     '2002': 4971000000.0,
#     '2003': 4733000000.0,
#     '2004': 6521000000.0,
#     '2005': 7161000000.0,
#     '2006': 8153000000.0,
#     '2007': 11729000000.0,
#     '2008': 12897000000.0,
#     '2009': 9888000000.0,
#     '2010': 9875000000.0,
#     '2011': 11471000000.0,
#     '2012': 11704000000.0,
#     '2013': 12242000000.0,
#     '2014': 12691000000.0,
#     '2015': 11164000000.0,
#     '2016': 11922000000.0,
#     '2017': 13925000000.0,
#     '2018': 15569000000.0,
#     '2019': 15712000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['38.71666667', '-9.133333']},
#    'properties': {'country': 'Portugal',
#     'country_code': 'PRT',
#     '1995': 5646000000.0,
#     '1996': 5572000000.0,
#     '1997': 5415000000.0,
#     '1998': 6390000000.0,
#     '1999': 6047000000.0,
#     '2000': 6029000000.0,
#     '2001': 6264000000.0,
#     '2002': 6643000000.0,
#     '2003': 7687000000.0,
#     '2004': 8902000000.0,
#     '2005': 9038000000.0,
#     '2006': 10487000000.0,
#     '2007': 12945000000.0,
#     '2008': 14081000000.0,
#     '2009': 12357000000.0,
#     '2010': 12984000000.0,
#     '2011': 14911000000.0,
#     '2012': 14578000000.0,
#     '2013': 16080000000.0,
#     '2014': 17577000000.0,
#     '2015': 16007000000.0,
#     '2016': 17347000000.0,
#     '2017': 21586000000.0,
#     '2018': 24366000000.0,
#     '2019': 24736000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['44.43333333', '26.1']},
#    'properties': {'country': 'Romania',
#     'country_code': 'ROU',
#     '1995': 689000000.0,
#     '1996': 670000000.0,
#     '1997': 603000000.0,
#     '1998': 351000000.0,
#     '1999': 306000000.0,
#     '2000': 394000000.0,
#     '2001': 419000000.0,
#     '2002': 400000000.0,
#     '2003': 523000000.0,
#     '2004': 607000000.0,
#     '2005': 1324000000.0,
#     '2006': 1675000000.0,
#     '2007': 2073000000.0,
#     '2008': 2626000000.0,
#     '2009': 1688000000.0,
#     '2010': 1631000000.0,
#     '2011': 2016000000.0,
#     '2012': 1904000000.0,
#     '2013': 2307000000.0,
#     '2014': 2388000000.0,
#     '2015': 2229000000.0,
#     '2016': 2474000000.0,
#     '2017': 3553000000.0,
#     '2018': 3879000000.0,
#     '2019': 4240000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['48.15', '17.116667']},
#    'properties': {'country': 'Slovakia',
#     'country_code': 'SVK',
#     '1995': 630000000.0,
#     '1996': 681000000.0,
#     '1997': 555000000.0,
#     '1998': 493000000.0,
#     '1999': 465000000.0,
#     '2000': 441000000.0,
#     '2001': 649000000.0,
#     '2002': 742000000.0,
#     '2003': 876000000.0,
#     '2004': 931000000.0,
#     '2005': 1282000000.0,
#     '2006': 1655000000.0,
#     '2007': 2352000000.0,
#     '2008': 3096000000.0,
#     '2009': 2541000000.0,
#     '2010': 2334000000.0,
#     '2011': 2515000000.0,
#     '2012': 2365000000.0,
#     '2013': 2702000000.0,
#     '2014': 2642000000.0,
#     '2015': 2480000000.0,
#     '2016': 2812000000.0,
#     '2017': 3024000000.0,
#     '2018': 3318000000.0,
#     '2019': 3353000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['46.05', '14.516667000000002']},
#    'properties': {'country': 'Slovenia',
#     'country_code': 'SVN',
#     '1995': 1128000000.0,
#     '1996': 1280000000.0,
#     '1997': 1225000000.0,
#     '1998': 1135000000.0,
#     '1999': 1011000000.0,
#     '2000': 1016000000.0,
#     '2001': 1059000000.0,
#     '2002': 1152000000.0,
#     '2003': 1427000000.0,
#     '2004': 1725000000.0,
#     '2005': 1894000000.0,
#     '2006': 2075000000.0,
#     '2007': 2464000000.0,
#     '2008': 2955000000.0,
#     '2009': 2817000000.0,
#     '2010': 2808000000.0,
#     '2011': 3048000000.0,
#     '2012': 2793000000.0,
#     '2013': 2966000000.0,
#     '2014': 3052000000.0,
#     '2015': 2594000000.0,
#     '2016': 2717000000.0,
#     '2017': 3057000000.0,
#     '2018': 3377000000.0,
#     '2019': 3240000000.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['46.91666667', '7.466667']},
#    'properties': {'country': 'Switzerland',
#     'country_code': 'CHE',
#     '1995': 11354000000.0,
#     '1996': 10779000000.0,
#     '1997': 10036000000.0,
#     '1998': 10188000000.0,
#     '1999': 9135000000.0,
#     '2000': 9058000000.0,
#     '2001': 9392000000.0,
#     '2002': 9198000000.0,
#     '2003': 10427000000.0,
#     '2004': 11217000000.0,
#     '2005': 11914000000.0,
#     '2006': 12961000000.0,
#     '2007': 14934000000.0,
#     '2008': 18016000000.0,
#     '2009': 17023000000.0,
#     '2010': 17883000000.0,
#     '2011': 20809000000.0,
#     '2012': 19564000000.0,
#     '2013': 20236000000.0,
#     '2014': 21358000000.0,
#     '2015': 20140000000.0,
#     '2016': 19787000000.0,
#     '2017': 20399000000.0,
#     '2018': 21294000000.0,
#     '2019': 21257000000.0}}]}
